# %% [markdown]
# # Using MLflow for Experiment Tracking and Model Management

# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# ML
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, classification_report, confusion_matrix


nltk.download("stopwords",quiet = True)
nltk.download("wordnet",quiet = True)

# MLflow
import mlflow
import mlflow.sklearn

# %% [markdown]
# # Load the Dataset

# %%
df = pd.read_csv("reviews_badminton/data.csv")
df.head()
# Out:
#             Reviewer Name               Review Title  \
# 0            Kamal Suresh               Nice product
# 1       Flipkart Customer     Don't waste your money
# 2  A. S. Raja Srinivasan   Did not meet expectations
# 3     Suresh Narayanasamy                       Fair
# 4               ASHIK P A                Over priced
#
#                Place of Review  Up Votes  Down Votes     Month  \
# 0   Certified Buyer, Chirakkal     889.0        64.0  Feb 2021
# 1   Certified Buyer, Hyderabad     109.0         6.0  Feb 2021
# 2  Certified Buyer, Dharmapuri      42.0         3.0  Apr 2021
# 3     Certified Buyer, Chennai      25.0         1.0       NaN
# 4                          NaN     147.0        24.0  Apr 2016
#
#                                          Review text  Ratings
# 0  Nice product, good quality, but price is now r...        4
# 1  They didn't supplied Yonex Mavis 350. Outside ...        1
# 2  Worst product. Damaged shuttlecocks packed in ...        1
# 3  Quite O. K. , but nowadays  the quality of the...        3
# 4  Over pricedJust â?¹620 ..from retailer.I didn'...        1

# %%
df.shape
# Out:
# (8518, 8)

# %% [markdown]
# # EDA (Exploratary Data Analysis)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8518 entries, 0 to 8517
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Reviewer Name    8508 non-null   object
#  1   Review Title     8508 non-null   object
#  2   Place of Review  8468 non-null   object
#  3   Up Votes         8508 non-null   float64
#  4   Down Votes       8508 non-null   float64
#  5   Month            8053 non-null   object
#  6   Review text      8510 non-null   object
#  7   Ratings          8518 non-null   int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 532.5+ KB

# %%
df.isnull().sum()
# Out:
# Reviewer Name       10
# Review Title        10
# Place of Review     50
# Up Votes            10
# Down Votes          10
# Month              465
# Review text          8
# Ratings              0
# dtype: int64

# %%
# Remove neutral reviews
df = df[df["Ratings"] != 3]

# Create sentiment label
df["sentiment"] = df["Ratings"].apply(lambda x: 1 if x >= 4 else 0)

# Combine title and review text
df["text"] = df["Review Title"].fillna("") + " " + df["Review text"].fillna("")
df = df[["text", "sentiment"]]
df.head()
# Out:
#                                                 text  sentiment
# 0  Nice product Nice product, good quality, but p...          1
# 1  Don't waste your money They didn't supplied Yo...          0
# 2  Did not meet expectations Worst product. Damag...          0
# 4  Over priced Over pricedJust â?¹620 ..from reta...          0
# 5  Mind-blowing purchase Good quality product. De...          1

# %% [markdown]
# # Text Preprocessing

# %%
stop_words = set(stopwords.words("english")) - {"not", "no", "never"}
lemmatizer = WordNetLemmatizer()

def preprocess(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"[^a-z\s]", "", text)
    words = text.split()
    words = [lemmatizer.lemmatize(w) for w in words if w not in stop_words]
    return " ".join(words)

# %%
df["processed_text"] = df["text"].apply(preprocess)
df.head()
# Out:
#                                                 text  sentiment  \
# 0  Nice product Nice product, good quality, but p...          1
# 1  Don't waste your money They didn't supplied Yo...          0
# 2  Did not meet expectations Worst product. Damag...          0
# 4  Over priced Over pricedJust â?¹620 ..from reta...          0
# 5  Mind-blowing purchase Good quality product. De...          1
#
#                                       processed_text
# 0  nice product nice product good quality price r...
# 1  dont waste money didnt supplied yonex mavis ou...
# 2  not meet expectation worst product damaged shu...
# 4  priced pricedjust retaileri didnt understand w...
# 5  mindblowing purchase good quality product deli...

# %% [markdown]
# # Train-Test Split

# %%
X = df["processed_text"]
y = df["sentiment"]

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42,stratify=y)

# %% [markdown]
# # TF-IDF Feature Extraction

# %%
tfidf = TfidfVectorizer(max_features=7000,ngram_range=(1, 2))

X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %% [markdown]
# # Set MLflow Experiment

# %%
# Silence MLflow + Alembic logs
import logging
import os

os.environ["ML_FLOW_DISABLE_GIT"]="true"
logging.getLogger("mlflow").setLevel(logging.ERROR)
logging.getLogger("alembic").setLevel(logging.ERROR)


mlflow.set_experiment("Sentiment_Analysis_Experiment_Tracking")
# Out:
# <Experiment: artifact_location='file:C:/Users/shaik syed basha/OneDrive/Desktop/New folder/mlruns/2', creation_time=1770395315078, experiment_id='2', last_update_time=1770395315078, lifecycle_stage='active', name='Sentiment_Analysis_Experiment_Tracking', tags={}>

# %% [markdown]
# # Train Multiple Models + Log to MLflow

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Naive Bayes": MultinomialNB(),
    "Linear SVM": LinearSVC(),
    "Random Forest": RandomForestClassifier(n_estimators=200, random_state=42)
}

results = {}

# %%
for name, model in models.items():
    with mlflow.start_run(run_name=name):

        model.fit(X_train_tfidf, y_train)
        preds = model.predict(X_test_tfidf)

        f1 = f1_score(y_test, preds, average="weighted")
        results[name] = f1

        # Log parameters
        mlflow.log_param("model_name", name)

        if name == "Logistic Regression":
            mlflow.log_param("max_iter", 1000)
        if name == "Random Forest":
            mlflow.log_param("n_estimators", 200)
        if name == "Linear SVM":
            mlflow.log_param("kernel", "linear")

        # Log metric
        mlflow.log_metric("f1_score", f1)

        # Confusion Matrix (Metric Plot)
        cm = confusion_matrix(y_test, preds)
        plt.figure(figsize=(4,4))
        plt.imshow(cm)
        plt.title(f"{name} Confusion Matrix")
        plt.colorbar()
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.savefig("confusion_matrix.png")
        plt.close()

        mlflow.log_artifact("confusion_matrix.png")

        # Log model
        mlflow.sklearn.log_model(sk_model=model, name="model")

        print(f"{name} F1-score: {f1:.4f}")
# Out:
# Logistic Regression F1-score: 0.9288
# Naive Bayes F1-score: 0.8713
# Linear SVM F1-score: 0.9474
# Random Forest F1-score: 0.9391

# %% [markdown]
# # Hyperparameter Tuning (Required for Hyperparameter Plots)

# %%
for c in [0.1, 1, 10]:
    with mlflow.start_run(run_name=f"LogReg_C={c}"):

        model = LogisticRegression(C=c, max_iter=1000)
        model.fit(X_train_tfidf, y_train)
        preds = model.predict(X_test_tfidf)

        f1 = f1_score(y_test, preds, average="weighted")

        mlflow.log_param("model", "LogisticRegression")
        mlflow.log_param("C", c)
        mlflow.log_metric("f1_score", f1)

        mlflow.sklearn.log_model(sk_model=model, name="model")

# %% [markdown]
# # Final Model Selection & Registration

# %%
best_model_name = max(results, key=results.get)
best_model_score = results[best_model_name]

print("\nFinal Model Selected:", best_model_name)
print("Best F1-score:", best_model_score)
# Out:
# Final Model Selected: Linear SVM
# Best F1-score: 0.947363331546774

# %%
final_model = models[best_model_name]
final_model.fit(X_train_tfidf, y_train)

with mlflow.start_run(run_name="Final_Model_Registration"):
    mlflow.sklearn.log_model(sk_model=final_model, name="final_model",registered_model_name="SentimentAnalysisModel")

    mlflow.log_param("final_model", best_model_name)
    mlflow.log_metric("best_f1_score", results[best_model_name])
# Out:
# Successfully registered model 'SentimentAnalysisModel'.
# Created version '1' of model 'SentimentAnalysisModel'.

# %% [markdown]
# ## MLflow Experiment Tracking with Auto Scheduling

# %%
pip install prefect
# Out:
# Requirement already satisfied: prefect in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (2.20.25)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: aiosqlite<1.0.0,>=0.17.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (0.22.1)
# Requirement already satisfied: alembic<2.0.0,>=1.7.5 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (1.18.3)
# Requirement already satisfied: apprise<2.0.0,>=1.8.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (1.9.7)
# Requirement already satisfied: asyncpg<0.32.0,>=0.23 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (0.31.0)
# Requirement already satisfied: click<8.2,>=8.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (8.1.7)
# Requirement already satisfied: cryptography>=36.0.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (43.0.0)
# Requirement already satisfied: dateparser<2.0.0,>=1.1.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (1.2.0)
# Requirement already satisfied: docker<8.0,>=4.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (6.1.3)
# Requirement already satisfied: graphviz>=0.20.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (0.21)
# Requirement already satisfied: jinja2<4.0.0,>=3.0.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (3.1.6)
# Requirement already satisfied: jinja2-humanize-extension>=0.4.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (0.4.0)
# Requirement already satisfied: humanize<5.0.0,>=4.9.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (4.15.0)
# Requirement already satisfied: kubernetes<32.0.0,>=24.2.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (29.0.0)
# Requirement already satisfied: pytz<2026,>=2021.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (2023.4)
# Requirement already satisfied: readchar<5.0.0,>=4.0.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (4.2.1)
# Requirement already satisfied: sqlalchemy!=1.4.33,<2.0.36,>=1.4.22 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from sqlalchemy[asyncio]!=1.4.33,<2.0.36,>=1.4.22->prefect) (2.0.34)
# Requirement already satisfied: typer!=0.12.2,<0.18.0,>=0.12.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (0.17.5)
# Requirement already satisfied: anyio<5.0,>=4.4.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (4.12.1)
# Requirement already satisfied: asgi-lifespan<3.0,>=1.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (2.1.0)
# Requirement already satisfied: cachetools<7.0,>=5.3 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (5.3.3)
# Requirement already satisfied: cloudpickle<4.0,>=2.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (3.1.2)
# Requirement already satisfied: coolname<3.0.0,>=1.0.4 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (2.2.0)
# Requirement already satisfied: croniter<6.0.0,>=1.0.12 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (2.0.7)
# Requirement already satisfied: fsspec>=2022.5.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (2024.6.1)
# Requirement already satisfied: exceptiongroup>=1.2.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (1.3.1)
# Requirement already satisfied: griffe<2.0.0,>=0.49.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (1.15.0)
# Requirement already satisfied: httpcore<2.0.0,>=1.0.5 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (1.0.9)
# Requirement already satisfied: httpx!=0.23.2,>=0.23 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from httpx[http2]!=0.23.2,>=0.23->prefect) (0.28.1)
# Requirement already satisfied: importlib-resources<6.5.0,>=6.1.3 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (6.4.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.32 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (1.33)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (4.23.0)
# Requirement already satisfied: orjson<4.0,>=3.7 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (3.11.7)
# Requirement already satisfied: packaging<25.1,>=21.3 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (24.1)
# Requirement already satisfied: pathspec>=0.8.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (0.10.3)
# Requirement already satisfied: pydantic!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect) (2.12.5)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.12.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (2.41.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (2.9.0.post0)
# Requirement already satisfied: python-slugify<9.0,>=5.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (5.0.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.4.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (6.0.1)
# Requirement already satisfied: rfc3339-validator<0.2.0,>=0.1.4 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (0.1.4)
# Requirement already satisfied: rich<15.0,>=11.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (13.9.4)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (0.18.6)
# Requirement already satisfied: sniffio<2.0.0,>=1.3.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (1.3.0)
# Requirement already satisfied: toml>=0.10.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (0.10.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.5.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (4.15.0)
# Requirement already satisfied: ujson<6.0.0,>=5.8.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (5.10.0)
# Requirement already satisfied: uvicorn!=0.29.0,>=0.14.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (0.40.0)
# Requirement already satisfied: websockets<14.0,>=10.4 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (13.1)
# Requirement already satisfied: itsdangerous in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (2.2.0)
# Requirement already satisfied: python-multipart>=0.0.7 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (0.0.22)
# Requirement already satisfied: pendulum<4,>=3.0.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from prefect) (3.2.0)
# Requirement already satisfied: Mako in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from alembic<2.0.0,>=1.7.5->prefect) (1.3.10)
# Requirement already satisfied: idna>=2.8 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from anyio<5.0,>=4.4.0->prefect) (3.7)
# Requirement already satisfied: requests in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from apprise<2.0.0,>=1.8.0->prefect) (2.32.3)
# Requirement already satisfied: requests-oauthlib in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from apprise<2.0.0,>=1.8.0->prefect) (2.0.0)
# Requirement already satisfied: markdown in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from apprise<2.0.0,>=1.8.0->prefect) (3.4.1)
# Requirement already satisfied: certifi in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from apprise<2.0.0,>=1.8.0->prefect) (2025.4.26)
# Requirement already satisfied: tzdata in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from apprise<2.0.0,>=1.8.0->prefect) (2023.3)
# Requirement already satisfied: colorama in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from click<8.2,>=8.0->prefect) (0.4.6)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from dateparser<2.0.0,>=1.1.1->prefect) (2024.9.11)
# Requirement already satisfied: tzlocal in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from dateparser<2.0.0,>=1.1.1->prefect) (5.3.1)
# Requirement already satisfied: urllib3>=1.26.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from docker<8.0,>=4.0->prefect) (2.2.3)
# Requirement already satisfied: websocket-client>=0.32.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from docker<8.0,>=4.0->prefect) (1.8.0)
# Requirement already satisfied: pywin32>=304 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from docker<8.0,>=4.0->prefect) (305.1)
# Requirement already satisfied: h11>=0.16 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from httpcore<2.0.0,>=1.0.5->prefect) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from jinja2<4.0.0,>=3.0.0->prefect) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from jsonpatch<2.0,>=1.32->prefect) (2.1)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from kubernetes<32.0.0,>=24.2.0->prefect) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from kubernetes<32.0.0,>=24.2.0->prefect) (2.48.0)
# Requirement already satisfied: oauthlib>=3.2.2 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from kubernetes<32.0.0,>=24.2.0->prefect) (3.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from pydantic!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect) (0.6.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from pydantic!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect) (0.4.2)
# Requirement already satisfied: email-validator>=2.0.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect) (2.3.0)
# Requirement already satisfied: text-unidecode>=1.3 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from python-slugify<9.0,>=5.0->prefect) (1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from rich<15.0,>=11.0->prefect) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from rich<15.0,>=11.0->prefect) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from sqlalchemy!=1.4.33,<2.0.36,>=1.4.22->sqlalchemy[asyncio]!=1.4.33,<2.0.36,>=1.4.22->prefect) (3.0.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from typer!=0.12.2,<0.18.0,>=0.12.0->prefect) (1.5.4)
# Requirement already satisfied: cffi>=1.12 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from cryptography>=36.0.1->prefect) (1.17.1)
# Requirement already satisfied: pycparser in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from cffi>=1.12->cryptography>=36.0.1->prefect) (2.21)
# Requirement already satisfied: dnspython>=2.0.0 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from email-validator>=2.0.0->pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect) (2.8.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from google-auth>=1.0.1->kubernetes<32.0.0,>=24.2.0->prefect) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from google-auth>=1.0.1->kubernetes<32.0.0,>=24.2.0->prefect) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes<32.0.0,>=24.2.0->prefect) (0.4.8)
# Requirement already satisfied: h2<5,>=3 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from httpx[http2]!=0.23.2,>=0.23->prefect) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect) (4.1.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich<15.0,>=11.0->prefect) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from requests->apprise<2.0.0,>=1.8.0->prefect) (3.3.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in C:\Users\shaik syed basha\anaconda3\Lib\site-packages (from ruamel.yaml>=0.17.0->prefect) (0.2.8)

# %%
#from prefect import flow, task

#@task
#def run_mlflow_pipeline():
#   print("Running MLflow sentiment analysis pipeline")

#@flow(name="Sentiment-MLflow-Pipeline")
#def sentiment_flow():
#    run_mlflow_pipeline()

#sentiment_flow()
